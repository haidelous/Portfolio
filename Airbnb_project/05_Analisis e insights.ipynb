# %% [markdown]
# # ANALISIS E INSIGHTS

# %% [markdown]
# Llegamos a la parte más importante, donde vamos a intentar obtener conclusiones relevantes para el objetivo utilizando todo el trabajo de preparación que hemos hecho, las técnicas de Business Analytics que ya conocemos y además vamos a aprender a crear una visualización en mapa.
#
# Para ello empezaremos dando respuesta a las preguntas semilla y es probable que en el proceso nos vayan surgiendo hallazgos interesantes que nos lleven a nuevas preguntas o a la aplicación de ciertas técnicas.

# %% [markdown]
# ## SET UP

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import sqlalchemy as sa

#Automcompletar rápido
# %config IPCompleter.greedy=True

pd.options.display.max_columns = None

# %% [markdown]
# ## CARGA DE DATOS

# %%
df = pd.read_pickle('datasets/Airbnb.pkl')
df
# Out:
#        index        id                                               name  \
# 0          0      6369           Rooftop terrace room ,  ensuite bathroom
# 1          1     21853                               Bright and airy room
# 2          2     23001                  Apartmento Arganzuela- Madrid Rio
# 3          3     24805                             Gran Via Studio Madrid
# 4          4     26825                 Single Room whith private Bathroom
# ...      ...       ...                                                ...
# 17705  17705  52182264  Enormous Private Room in 12-Bedroom Unit - los...
# 17706  17706  52182273  Stunning Private Room in 11-Bedroom Unit - los...
# 17707  17707  52182303  Classic Private Room in 7-Bedroom Unit - los 3...
# 17708  17708  52182321  Elegant Private Room in 12-Bedroom Unit - los ...
# 17709  17709  52182334  Fashioned Private Room in 12-Bedroom Unit - lo...
#
#          host_id neighbourhood_group   neighbourhood   latitude  longitude  \
# 0          13660           Chamartín  Hispanoamérica  40.457240  -3.676880
# 1          83531              Latina        Cármenes  40.403810  -3.741300
# 2          82175          Arganzuela         Legazpi  40.388400  -3.695110
# 3      346366726              Centro     Universidad  40.421830  -3.705290
# 4         114340          Arganzuela         Legazpi  40.389750  -3.690180
# ...          ...                 ...             ...        ...        ...
# 17705  378060726              Centro        Justicia  40.424384  -3.691216
# 17706  378060726              Centro        Justicia  40.424447  -3.691309
# 17707  378060726              Centro        Justicia  40.424989  -3.691783
# 17708  378060726           Salamanca       Recoletos  40.424352  -3.690211
# 17709  378060726              Centro        Justicia  40.425670  -3.691727
#
#              room_type  price  minimum_nights  calculated_host_listings_count  \
# 0         Private room     60               1                               2
# 1         Private room     31               4                               2
# 2      Entire home/apt     50              15                               5
# 3      Entire home/apt     92               5                               1
# 4         Private room     26               2                               1
# ...                ...    ...             ...                             ...
# 17705     Private room     29               1                              87
# 17706     Private room     29               1                              87
# 17707     Private room     29               1                              87
# 17708     Private room     29               1                              87
# 17709     Private room     33               1                              87
#
#        availability_365                                        description  \
# 0                   180  Excellent connection with the AIRPORT and EXHI...
# 1                   364  We have a quiet and sunny room with a good vie...
# 2                   222  Apartamento de tres dormitorios dobles, gran s...
# 3                   115  Studio located 50 meters from Gran Via, next t...
# 4                   349  Nice and cozy roon for one person with a priva...
# ...                 ...                                                ...
# 17705               358  ROOM - 8 sqm. • 1st Floor <br /> <br />cozy ro...
# 17706               358  ROOM - 10 sqm. • 4th Floor <br /> <br />cozy r...
# 17707               358  ROOM <br /> <br />cozy room in madrid centro i...
# 17708               358  ROOM -9 sqm. • 1st Floor <br /> <br />cozy roo...
# 17709               358  ROOM - 10 sqm. • 1st Floor <br /> <br />cozy r...
#
#       host_is_superhost  accommodates  bedrooms  beds  number_of_reviews  \
# 0                     t             2       1.0   1.0                 80
# 1                     f             1       1.0   1.0                 33
# 2                     f             6       3.0   5.0                  0
# 3                     f             3       1.0   1.0                 12
# 4                     f             1       1.0   1.0                149
# ...                 ...           ...       ...   ...                ...
# 17705                 f             1       1.0   0.0                  0
# 17706                 f             1       1.0   0.0                  0
# 17707                 f             1       1.0   0.0                  0
# 17708                 f             1       1.0   0.0                  0
# 17709                 f             1       1.0   0.0                  0
#
#        review_scores_rating  review_scores_communication  \
# 0                      4.87                         4.89
# 1                      4.58                         4.82
# 2                       NaN                          NaN
# 3                      4.92                         5.00
# 4                      4.68                         4.71
# ...                     ...                          ...
# 17705                   NaN                          NaN
# 17706                   NaN                          NaN
# 17707                   NaN                          NaN
# 17708                   NaN                          NaN
# 17709                   NaN                          NaN
#
#        review_scores_location  precio_m2    distrito  precio_total  ocupation  \
# 0                        4.77       5098   Chamartín          60.0         50
# 1                        4.21       2267      Latina          31.0          0
# 2                         NaN       4085  Arganzuela          50.0         39
# 3                        5.00       4827      Centro          92.0         68
# 4                        4.70       4085  Arganzuela          26.0          4
# ...                       ...        ...         ...           ...        ...
# 17705                     NaN       4827      Centro          29.0          1
# 17706                     NaN       4827      Centro          29.0          1
# 17707                     NaN       4827      Centro          29.0          1
# 17708                     NaN       6114   Salamanca          29.0          1
# 17709                     NaN       4827      Centro          33.0          1
#
#       bedrooms_disc  m2  price_buy   pdi_sol accommodates_disc beds_disc  \
# 0            01_one  50   178430.0  5.032039               0-3         1
# 1            01_one  50    79345.0  3.521406               0-3         1
# 2          03_three  90   257355.0  3.226963              5-16      3-24
# 3            01_one  50   168945.0  0.591065               0-3         1
# 4            01_one  50   142975.0  3.200942               0-3         1
# ...             ...  ..        ...       ...               ...       ...
# 17705        01_one  50   168945.0  1.333715               0-3         1
# 17706        01_one  50   168945.0  1.332195               0-3         1
# 17707        01_one  50   168945.0  1.342319               0-3         1
# 17708        01_one  50   213990.0  1.398097               0-3         1
# 17709        01_one  50   168945.0  1.398558               0-3         1
#
#       number_of_reviews_disc
# 0                     48-744
# 1                       5-48
# 2                        1-4
# 3                       5-48
# 4                     48-744
# ...                      ...
# 17705                    1-4
# 17706                    1-4
# 17707                    1-4
# 17708                    1-4
# 17709                    1-4
#
# [17710 rows x 33 columns]

# %%
#con = sa.create_engine('sqlite:///datasets/airbnb.db')

#df = pd.read_sql('df_preparado', con = con)

#df.head()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17710 entries, 0 to 17709
# Data columns (total 33 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   index                           17710 non-null  int64
#  1   id                              17710 non-null  int64
#  2   name                            17707 non-null  object
#  3   host_id                         17710 non-null  int64
#  4   neighbourhood_group             17710 non-null  object
#  5   neighbourhood                   17710 non-null  object
#  6   latitude                        17710 non-null  float64
#  7   longitude                       17710 non-null  float64
#  8   room_type                       17710 non-null  object
#  9   price                           17710 non-null  int64
#  10  minimum_nights                  17710 non-null  int64
#  11  calculated_host_listings_count  17710 non-null  int64
#  12  availability_365                17710 non-null  int64
#  13  description                     16766 non-null  object
#  14  host_is_superhost               17685 non-null  object
#  15  accommodates                    17710 non-null  int64
#  16  bedrooms                        17710 non-null  float64
#  17  beds                            17710 non-null  float64
#  18  number_of_reviews               17710 non-null  int64
#  19  review_scores_rating            13084 non-null  float64
#  20  review_scores_communication     12863 non-null  float64
#  21  review_scores_location          12860 non-null  float64
#  22  precio_m2                       17710 non-null  int64
#  23  distrito                        17710 non-null  object
#  24  precio_total                    17710 non-null  float64
#  25  ocupation                       17710 non-null  int32
#  26  bedrooms_disc                   17710 non-null  object
#  27  m2                              17710 non-null  int32
#  28  price_buy                       17710 non-null  float64
#  29  pdi_sol                         17710 non-null  float64
#  30  accommodates_disc               17710 non-null  category
#  31  beds_disc                       17710 non-null  category
#  32  number_of_reviews_disc          17710 non-null  category
# dtypes: category(3), float64(10), int32(2), int64(10), object(8)
# memory usage: 4.0+ MB

# %% [markdown]
# ## ANALISIS

# %% [markdown]
# ### Analisis sobre el precio

# %% [markdown]
# **¿Cual es el precio medio? ¿y el rango de precios?¿Y por distritos?¿Y por barrios?**
#
# **¿Cual es el ranking de distritos y barrios por precio medio de alquiler?**

# %%
df.precio_total.describe()
# Out:
# count    17710.000000
# mean       149.027770
# std        523.211567
# min         20.000000
# 25%         43.000000
# 50%         70.000000
# 75%        112.000000
# max      22400.000000
# Name: precio_total, dtype: float64

# %% [markdown]
# Vemos que hay al menos un atípico por la parte de arriba que sesga la media, por tanto vamos a usar la mediana como medida de centralización más fiable.

# %%
df.precio_total.median()
# Out:
# 70.0

# %%
df.groupby('distrito').precio_total.median().sort_values(ascending = False)
# Out:
# distrito
# San Blas - Canillejas    90.0
# Salamanca                88.0
# Centro                   76.0
# Chamartín                74.0
# Chamberí                 70.0
# Hortaleza                69.0
# Retiro                   68.0
# Tetuán                   66.0
# Moncloa - Aravaca        61.0
# Fuencarral - El Pardo    60.0
# Arganzuela               58.0
# Vicálvaro                53.0
# Ciudad Lineal            50.0
# Barajas                  49.5
# Carabanchel              48.0
# Villa de Vallecas        47.5
# Latina                   47.0
# Usera                    42.0
# Villaverde               42.0
# Moratalaz                40.0
# Puente de Vallecas       40.0
# Name: precio_total, dtype: float64

# %% [markdown]
# Nos llama la atención el dato de San Blas, vamos a verlo con más detalle a ver qué está pasando.

# %%
df.loc[df.distrito == 'San Blas - Canillejas'].sort_values('precio_total',ascending = False).head(10)
# Out:
#        level_0  index        id  \
# 9290      9290   9290  34600594
# 9662      9662   9662  34826962
# 10189    10189  10189  35149419
# 9668      9668   9668  34833756
# 9878      9878   9878  34970236
# 9748      9748   9748  34882596
# 9173      9173   9173  34522997
# 9831      9831   9831  34933116
# 10092    10092  10092  35091283
# 10404    10404  10404  35251141
#
#                                                     name    host_id  \
# 9290                                  3 rooms near Wanda   38951538
# 9662                                         Pozos rooms  222068421
# 10189       CHALET FOR THE FINAL CHAMPIONS LEAGUE MADRID  143732655
# 9668                               Wanda Champions Final   29628177
# 9878   Habitaciones cerca Wanda Metropolitano (Champi...  263474389
# 9748                                  2 rooms near wanda   38951538
# 9173     Beautiful Penthouse next to Wanda Metropolitano  260551569
# 9831                       FINAL CHAMPIONS LEAGUE MADRID  263232278
# 10092                             FINAL CHAMPIONS LEAGUE  264225539
# 10404        Se alquila para final de la champion league  265376740
#
#          neighbourhood_group neighbourhood  latitude  longitude  \
# 9290   San Blas - Canillejas         Arcos  40.42105   -3.61457
# 9662   San Blas - Canillejas         Arcos  40.41927   -3.61555
# 10189  San Blas - Canillejas    Canillejas  40.44937   -3.61633
# 9668   San Blas - Canillejas         Rosas  40.42622   -3.60502
# 9878   San Blas - Canillejas         Arcos  40.41920   -3.61229
# 9748   San Blas - Canillejas         Arcos  40.41948   -3.61427
# 9173   San Blas - Canillejas    Canillejas  40.43686   -3.61093
# 9831   San Blas - Canillejas      Simancas  40.43968   -3.61933
# 10092  San Blas - Canillejas         Rejas  40.44592   -3.58746
# 10404  San Blas - Canillejas    Canillejas  40.44292   -3.60764
#
#              room_type  price  minimum_nights  calculated_host_listings_count  \
# 9290      Private room   2800               1                               2
# 9662      Private room   3000               1                               1
# 10189  Entire home/apt   6000               1                               1
# 9668      Private room   2700               1                               1
# 9878      Private room    800               1                               1
# 9748      Private room   1500               1                               2
# 9173      Private room   2000               1                               1
# 9831      Private room   2000               2                               1
# 10092     Private room   1000               1                               1
# 10404  Entire home/apt   3000               1                               1
#
#        availability_365                                        description  \
# 9290                  0                     3 rooms 15´walking from Wanda.
# 9662                 88  Cerca nos podemos encontrar un centro comercia...
# 10189               365  We are talking about one of the last villas fo...
# 9668                  0  Somos una pareja joven educados y muy sociable...
# 9878                 88  Se alquilan 5 habitaciones, cada una para 2 hu...
# 9748                363  2 rooms near Wanda stadium (20' walking) with ...
# 9173                  0  Wonderful penthouse in a lovely duplex next to...
# 9831                365  Near (15 minutes walking) to WANDA STADIUM.<br...
# 10092               180  Desayuno, comida y cena incluida. Traslados al...
# 10404               365                                               None
#
#       host_is_superhost  accommodates  bedrooms  beds  number_of_reviews  \
# 9290                  f             6       3.0   5.0                  0
# 9662                  f             4       2.0   3.0                  0
# 10189                 f             6       4.0   5.0                  0
# 9668                  f             5       2.0   3.0                  0
# 9878                  f            10       5.0   8.0                  0
# 9748                  f             4       2.0   4.0                  0
# 9173                  f             4       1.0   3.0                  0
# 9831                  f             5       3.0   3.0                  0
# 10092                 f             6       2.0   6.0                  0
# 10404                 f             1       2.0   4.0                  0
#
#        review_scores_rating  review_scores_communication  \
# 9290                    NaN                          NaN
# 9662                    NaN                          NaN
# 10189                   NaN                          NaN
# 9668                    NaN                          NaN
# 9878                    NaN                          NaN
# 9748                    NaN                          NaN
# 9173                    NaN                          NaN
# 9831                    NaN                          NaN
# 10092                   NaN                          NaN
# 10404                   NaN                          NaN
#
#        review_scores_location  precio_m2               distrito  precio_total  \
# 9290                      NaN       2591  San Blas - Canillejas        9800.0
# 9662                      NaN       2591  San Blas - Canillejas        6300.0
# 10189                     NaN       2591  San Blas - Canillejas        6000.0
# 9668                      NaN       2591  San Blas - Canillejas        5670.0
# 9878                      NaN       2591  San Blas - Canillejas        4480.0
# 9748                      NaN       2591  San Blas - Canillejas        4200.0
# 9173                      NaN       2591  San Blas - Canillejas        4200.0
# 9831                      NaN       2591  San Blas - Canillejas        4200.0
# 10092                     NaN       2591  San Blas - Canillejas        4200.0
# 10404                     NaN       2591  San Blas - Canillejas        3000.0
#
#        ocupacion    bedrooms_disc accommodates_disc beds_disc  \
# 9290         100          03_Tres              5-16      3-24
# 9662          75           02_Dos                 4         2
# 10189          0  04_Cuatro o mas              5-16      3-24
# 9668         100           02_Dos              5-16         2
# 9878          75  04_Cuatro o mas              5-16      3-24
# 9748           0           02_Dos                 4      3-24
# 9173         100           01_Una                 4         2
# 9831           0          03_Tres              5-16         2
# 10092         50           02_Dos              5-16      3-24
# 10404          0           02_Dos               0-3      3-24
#
#       number_of_reviews_disc   m2  precio_compra    pdi_sol
# 9290                     1-4   90       163233.0   7.532233
# 9662                     1-4   70       126959.0   7.439364
# 10189                    1-4  120       217644.0   8.212429
# 9668                     1-4   70       126959.0   8.391922
# 9878                     1-4  150       272055.0   7.714952
# 9748                     1-4   70       126959.0   7.548577
# 9173                     1-4   50        90685.0   8.138310
# 9831                     1-4   90       163233.0   7.557076
# 10092                    1-4   70       126959.0  10.334061
# 10404                    1-4   70       126959.0   8.610212

# %% [markdown]
# Vemos que son precios en el entorno de los 3.000 - 5.000 euros!
#
# Al leer la descripción nos damos cuenta de todos estos precios están definidos por la final de la Champions League.
#
# Lo cual es un insight interesante:
#
# **Insight 1: pueden existir inmuebles con un valor regular residual pero con alto valor en momentos puntuales por acontenicimientos deportivos o espectáculos**
#
# ¿Tendría sentido generar un producto de alquiler que consista en alquilar de forma "normal" a un precio inferior al mercado con la condición de que el inquilino deje el piso libre para alquilarlo "turísticamente" en fechas señaladas?

# %% [markdown]
# En el resto no hay sorpresas, con distritos como Salamanca, Centro o Chanmartín a la cabeza.
#
# Pero por ejemplo vemos que la diferencia de precio media entre Retiro y Tetuán es muy baja.
#
# Esto nos lleva a comparar el precio medio por distrito con el precio medio de compra también por distrito.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17710 entries, 0 to 17709
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              17710 non-null  int64
#  1   name                            17707 non-null  object
#  2   host_id                         17710 non-null  int64
#  3   neighbourhood_group             17710 non-null  object
#  4   neighbourhood                   17710 non-null  object
#  5   latitude                        17710 non-null  float64
#  6   longitude                       17710 non-null  float64
#  7   room_type                       17710 non-null  object
#  8   price                           17710 non-null  int64
#  9   minimum_nights                  17710 non-null  int64
#  10  calculated_host_listings_count  17710 non-null  int64
#  11  availability_365                17710 non-null  int64
#  12  description                     16766 non-null  object
#  13  host_is_superhost               17685 non-null  object
#  14  accommodates                    17710 non-null  int64
#  15  bedrooms                        17710 non-null  float64
#  16  beds                            17710 non-null  float64
#  17  number_of_reviews               17710 non-null  int64
#  18  review_scores_rating            13084 non-null  float64
#  19  review_scores_communication     12863 non-null  float64
#  20  review_scores_location          12860 non-null  float64
#  21  precio_m2                       17710 non-null  int64
#  22  distrito                        17710 non-null  object
#  23  precio_total                    17710 non-null  float64
#  24  ocupation                       17710 non-null  int64
#  25  bedrooms_disc                   17710 non-null  object
#  26  m2                              17710 non-null  int64
#  27  price_buy                       17710 non-null  float64
#  28  pdi_sol                         17710 non-null  float64
# dtypes: float64(10), int64(11), object(8)
# memory usage: 3.9+ MB

# %%
temp = df.groupby('distrito')[['precio_total','price_buy']].median()
temp
# Out:
#                        precio_total  price_buy
# distrito
# Arganzuela                     58.0   142975.0
# Barajas                        49.5   119315.0
# Carabanchel                    48.0    74305.0
# Centro                         76.0   168945.0
# Chamartín                      74.0   178430.0
# Chamberí                       70.0   188335.0
# Ciudad Lineal                  50.0   102900.0
# Fuencarral - El Pardo          60.0   124880.0
# Hortaleza                      69.0   135485.0
# Latina                         47.0    79345.0
# Moncloa - Aravaca              61.0   141155.0
# Moratalaz                      40.0    87500.0
# Puente de Vallecas             40.0    67130.0
# Retiro                         68.0   167580.0
# Salamanca                      88.0   213990.0
# San Blas - Canillejas          90.0    90685.0
# Tetuán                         66.0   128730.0
# Usera                          42.0    69825.0
# Vicálvaro                      53.0    84105.0
# Villa de Vallecas              47.5    82390.0
# Villaverde                     42.0    59255.0

# %%
plt.figure(figsize=(16,8))
sns.scatterplot(data=temp, x='price_buy', y='precio_total')
#colocando etiquetas
for i in range(0, temp.shape[0]):
    plt.text(temp.price_buy.iloc[i], temp.precio_total.iloc[i], temp.index[i])

# %% [markdown]
# Existe una clara correlación entre el precio de compra en cada distrito y el precio que podremos cobrar.
#
# Claramente se perciben tres clusters de bajo-bajo, medio-medio y alto-alto.
#
# Y la excepción de San Blas que ya sabemos por qué es.
#
# Por tanto como era esperable no hay a priori ningún "chollo" claro a este nivel.
#
# Vamos a repetir el análisis a nivel de barrio a ver si identificamos algo.

# %%
temp = df.groupby('neighbourhood')[['precio_total','precio_compra']].median()
temp
# Out:
#                precio_total  precio_compra
# neighbourhood
# Abrantes               35.5        74305.0
# Acacias                53.8       142975.0
# Adelfas                54.0       234612.0
# Aeropuerto             41.3       119315.0
# Aguilas                47.0        79345.0
# ...                     ...            ...
# Valverde               62.5       124880.0
# Ventas                 42.0       102900.0
# Vinateros              50.0        87500.0
# Vista Alegre           50.0        74305.0
# Zofío                  36.4        69825.0
#
# [128 rows x 2 columns]

# %%
plt.figure(figsize = (16,20))
sns.scatterplot(data = temp, x = 'precio_compra', y = 'precio_total')
#Ponemos las etiquetas
for cada in range(0,temp.shape[0]):
    plt.text(temp.precio_compra.iloc[cada], temp.precio_total.iloc[cada], temp.index[cada])

# %% [markdown]
# A este nivel ya vemos más cosas:
#
# * 3 barrios que sobresalen, posiblemente los 3 sean de San Blas
# * Dentro de cada grupo de bajo-medio-alto sí podemos empezar a separarar
#     * Bajo: Simancas, Ambroz, Marroquina, San Juan Bautista
#     * Medio: El Plantio, Valdemarín, Valdefuentes
#     * Medio-alto: Jerónimos, Fuentela reina
#     * Alto: Recoletos
#
# **Insight 2: Existen ciertos barrios que apriori pueden maximizar la relación coste-ingresos y además podemos segmentarlo por el tipo calidad del inmueble en el que nos interesa invertir**

# %%
df.loc[df.neighbourhood.isin(['Rosas','Canillejas','Hellin']),'distrito'].unique()
# Out:
# array(['San Blas - Canillejas'], dtype=object)

# %% [markdown]
# **¿Qué factores (a parte de la localización determinan el precio del alquiler?**

# %% [markdown]
# Para responder a esta pregunta podemos construir un minicubo, ya que hemos discretizado nuestras variables de análisis.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17710 entries, 0 to 17709
# Data columns (total 33 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   index                           17710 non-null  int64
#  1   id                              17710 non-null  int64
#  2   name                            17707 non-null  object
#  3   host_id                         17710 non-null  int64
#  4   neighbourhood_group             17710 non-null  object
#  5   neighbourhood                   17710 non-null  object
#  6   latitude                        17710 non-null  float64
#  7   longitude                       17710 non-null  float64
#  8   room_type                       17710 non-null  object
#  9   price                           17710 non-null  int64
#  10  minimum_nights                  17710 non-null  int64
#  11  calculated_host_listings_count  17710 non-null  int64
#  12  availability_365                17710 non-null  int64
#  13  description                     16766 non-null  object
#  14  host_is_superhost               17685 non-null  object
#  15  accommodates                    17710 non-null  int64
#  16  bedrooms                        17710 non-null  float64
#  17  beds                            17710 non-null  float64
#  18  number_of_reviews               17710 non-null  int64
#  19  review_scores_rating            13084 non-null  float64
#  20  review_scores_communication     12863 non-null  float64
#  21  review_scores_location          12860 non-null  float64
#  22  precio_m2                       17710 non-null  int64
#  23  distrito                        17710 non-null  object
#  24  precio_total                    17710 non-null  float64
#  25  ocupation                       17710 non-null  int32
#  26  bedrooms_disc                   17710 non-null  object
#  27  m2                              17710 non-null  int32
#  28  price_buy                       17710 non-null  float64
#  29  pdi_sol                         17710 non-null  float64
#  30  accommodates_disc               17710 non-null  category
#  31  beds_disc                       17710 non-null  category
#  32  number_of_reviews_disc          17710 non-null  category
# dtypes: category(3), float64(10), int32(2), int64(10), object(8)
# memory usage: 4.0+ MB

# %%
#Paso 1: Seleccionar qué variables serán la métricas y cuales las dimensiones
metricas = ['precio_total','price_buy']
dimensiones = ['bedrooms_disc','accommodates_disc','beds_disc','number_of_reviews_disc']

minicubo_precio = df[dimensiones + metricas]
minicubo_precio
# Out:
#       bedrooms_disc accommodates_disc beds_disc number_of_reviews_disc  \
# 0            01_one               0-3         1                 48-744
# 1            01_one               0-3         1                   5-48
# 2          03_three              5-16      3-24                    1-4
# 3            01_one               0-3         1                   5-48
# 4            01_one               0-3         1                 48-744
# ...             ...               ...       ...                    ...
# 17705        01_one               0-3         1                    1-4
# 17706        01_one               0-3         1                    1-4
# 17707        01_one               0-3         1                    1-4
# 17708        01_one               0-3         1                    1-4
# 17709        01_one               0-3         1                    1-4
#
#        precio_total  price_buy
# 0              60.0   178430.0
# 1              31.0    79345.0
# 2              50.0   257355.0
# 3              92.0   168945.0
# 4              26.0   142975.0
# ...             ...        ...
# 17705          29.0   168945.0
# 17706          29.0   168945.0
# 17707          29.0   168945.0
# 17708          29.0   213990.0
# 17709          33.0   168945.0
#
# [17710 rows x 6 columns]

# %%
#Paso 2: pasar a transaccional las dimensiones
minicubo_precio = minicubo_precio.melt(id_vars=['precio_total','price_buy'])
minicubo_precio
# Out:
#        precio_total  price_buy                variable     value
# 0              60.0   178430.0           bedrooms_disc    01_one
# 1              31.0    79345.0           bedrooms_disc    01_one
# 2              50.0   257355.0           bedrooms_disc  03_three
# 3              92.0   168945.0           bedrooms_disc    01_one
# 4              26.0   142975.0           bedrooms_disc    01_one
# ...             ...        ...                     ...       ...
# 70835          29.0   168945.0  number_of_reviews_disc       1-4
# 70836          29.0   168945.0  number_of_reviews_disc       1-4
# 70837          29.0   168945.0  number_of_reviews_disc       1-4
# 70838          29.0   213990.0  number_of_reviews_disc       1-4
# 70839          33.0   168945.0  number_of_reviews_disc       1-4
#
# [70840 rows x 4 columns]

# %%
#Paso 3: Agregar las métricas por "variable" y "valor" con las funciones deseadas
minicubo_precio = minicubo_precio.groupby(['variable','value'])[['precio_total','price_buy']].agg('median')
minicubo_precio
# Out:
#                                         precio_total  price_buy
# variable               value
# accommodates_disc      0-3                      50.0   168945.0
#                        4                        86.0   168945.0
#                        5-16                    126.0   236523.0
# bedrooms_disc          01_one                   56.0   168945.0
#                        02_two                  100.0   236523.0
#                        03_three                140.0   304101.0
#                        04_four_or_more         204.0   405468.0
# beds_disc              1                        59.0   168945.0
#                        2                       100.0   236523.0
#                        3-24                    139.0   257355.0
# number_of_reviews_disc 1-4                      70.0   168945.0
#                        48-744                   68.0   168945.0
#                        5-48                     69.0   168945.0

# %% [markdown]
# Sobre el minicubo vamos analizando cada variable.

# %%
minicubo_precio.loc['bedrooms_disc']
# Out:
#                  precio_total  price_buy
# value
# 01_one                   56.0   168945.0
# 02_two                  100.0   236523.0
# 03_three                140.0   304101.0
# 04_four_or_more         204.0   405468.0

# %%
f, ax = plt.subplots(figsize=(10, 6))
ax.plot(minicubo_precio.loc['bedrooms_disc'].index, 
        minicubo_precio.loc['bedrooms_disc'].precio_total, 
        label='Precio Total') 
ax2 = ax.twinx()
ax2.plot(minicubo_precio.loc['bedrooms_disc'].index, 
        minicubo_precio.loc['bedrooms_disc'].price_buy, 
        color='green', label='price_buy')

ax.set_xlabel('Índice') 
ax.set_ylabel('Precio Total', color='blue')
ax2.set_ylabel('price_buy', color='green')
ax.legend(loc='upper left')
ax2.legend(loc='upper right')
plt.title('Comparación de Precios')
plt.show()

# %% [markdown]
# En cuanto al número de habitaciones no hay nada que destacar.
#
# Existe una relación casi perfecta entre el precio de compra y el precio total que se puede cobrar.
#
# Parte de este efecto puede ser artificial, ya que usamos el número de habitaciones para calcular el precio total como el precio de compra.

# %%
minicubo_precio.loc['beds_disc']
# Out:
#        precio_total  precio_compra
# value
# 1              59.0       168945.0
# 2             100.0       236523.0
# 3-24          139.0       257355.0

# %%
fig, ax = plt.subplots(figsize=(10, 6)) 
ax.plot(minicubo_precio.loc['beds_disc'].index, 
        minicubo_precio.loc['beds_disc'].precio_total, 
        label='Precio Total', 
        color='blue', 
        linewidth=2, 
        marker='o') 

ax2 = ax.twinx()
ax2.plot(minicubo_precio.loc['beds_disc'].index, 
        minicubo_precio.loc['beds_disc'].price_buy, 
        label='price_buy', 
        color='green', 
        linewidth=2, 
        marker='s')

ax.set_xlabel('Índice') 
ax.set_ylabel('Precio Total', color='blue')
ax2.set_ylabel('price_buy', color='green')
plt.title('Comparación de Precios')

ax.grid(True, linestyle='--', alpha=0.5)
ax2.grid(True, linestyle='--', alpha=0.5)

lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax.legend(lines + lines2, labels + labels2, loc='upper left')

plt.show();

# %% [markdown]
# En cuanto al número de camas sí hay una conclusión:
#
# **Insight 3: el número de camas a evitar es 2**. O bien ponemos una cama o intentamos meter todas las posibles.
#
# Dado que no había este efecto en el número de habitaciones ¿podría ser que los propietarios estén intentando meter muchas más camas que habitaciones para maximizar el ingreso?
#
# Veámoslo por ejemplo con los pisos de una habitación:

# %%
df[df.bedrooms == 1].groupby('beds').price_buy.median().plot();

# %% [markdown]
# Efectivamente aquí hay algo, ya que figura que para pisos de una habitación hay gente que está metiendo hasta decenas de camas!
#
# Sería un tema a explorar con más detalle y comentar con alguien que conozca el negocio.
#
# Vamos a ver unos ejemplos:

# %%
df.loc[(df.bedrooms == 1)& (df.beds > 8)]
# Out:
#        level_0  index        id  \
# 357        357    357   1044902
# 605        605    605   2143824
# 710        710    710   3011110
# 11848    11848  11848  39600798
# 13340    13340  13340  42492960
# 15722    15722  15722  48855617
#
#                                                     name    host_id  \
# 357                                    Masía el Ferrajón    5751753
# 605                    The Hat Madrid - 10 people shared   10940437
# 710                  The Hat Madrid-Compartida 10 pers 2   10940437
# 11848  Bed in a 10-Bed Dormitory In the Centre of Madrid  304035848
# 13340              Apartamento dúplex 10camas en literas  338384437
# 15722   habitaciones en una casa tranquila, en el centro  194738186
#
#       neighbourhood_group         neighbourhood  latitude  longitude  \
# 357     Moncloa - Aravaca  Ciudad Universitaria  40.46549   -3.75115
# 605                Centro                   Sol  40.41511   -3.70804
# 710                Centro           Embajadores  40.41311   -3.70621
# 11848              Centro              Justicia  40.42710   -3.69912
# 13340              Tetuán        Cuatro Caminos  40.44959   -3.70138
# 15722           Salamanca      Fuente del Berro  40.42604   -3.66373
#
#           room_type  price  minimum_nights  calculated_host_listings_count  \
# 357    Private room    112               2                               1
# 605     Shared room     24               1                               6
# 710     Shared room     24               1                               6
# 11848   Shared room     20               1                              13
# 13340  Private room    298               1                               1
# 15722  Private room     36               2                               1
#
#        availability_365                                        description  \
# 357                   0  <b>The space</b><br />Masía el Ferrajón featur...
# 605                 364  10 people shared room with shared bathroom. <b...
# 710                 364  The Hat Madrid es el primer Boutique Hostel de...
# 11848               351  Low-key, hostel-style setup on a tree-lined st...
# 13340               364  Vivienda en planta baja con 10 plazas distribu...
# 15722               359  Es una casa que tiene dos habitaciones que se ...
#
#       host_is_superhost  accommodates  bedrooms  beds  number_of_reviews  \
# 357                   f            16       1.0  14.0                  0
# 605                   t            10       1.0  10.0                 91
# 710                   t            10       1.0  10.0                 28
# 11848                 f             1       1.0  10.0                  2
# 13340                 f            10       1.0  10.0                  1
# 15722                 f             5       1.0   9.0                  0
#
#        review_scores_rating  review_scores_communication  \
# 357                     NaN                          NaN
# 605                    4.57                         4.69
# 710                    4.56                         4.81
# 11848                  5.00                         5.00
# 13340                  5.00                         4.00
# 15722                   NaN                          NaN
#
#        review_scores_location  precio_m2           distrito  precio_total  \
# 357                       NaN       4033  Moncloa - Aravaca        1097.6
# 605                      4.84       4827             Centro         168.0
# 710                      4.93       4827             Centro         168.0
# 11848                    5.00       4827             Centro         140.0
# 13340                    5.00       3678             Tetuán        2086.0
# 15722                     NaN       6114          Salamanca         226.8
#
#        ocupacion bedrooms_disc accommodates_disc beds_disc  \
# 357          100        01_Una              5-16      3-24
# 605            0        01_Una              5-16      3-24
# 710            0        01_Una              5-16      3-24
# 11848          3        01_Una               0-3      3-24
# 13340          0        01_Una              5-16      3-24
# 15722          1        01_Una              5-16      3-24
#
#       number_of_reviews_disc  m2  precio_compra   pdi_sol
# 357                      1-4  50       141155.0  6.767308
# 605                   48-744  50       168945.0  0.436897
# 710                     5-48  50       168945.0  0.470155
# 11848                    1-4  50       168945.0  1.207701
# 13340                    1-4  50       128730.0  3.658902
# 15722                    1-4  50       213990.0  3.510206

# %% [markdown]
# Vamos a analizar ahora por el número de huéspedes que aceptan

# %%
minicubo_precio.loc['accommodates_disc']
# Out:
#        precio_total  price_buy
# value
# 0-3            50.0   168945.0
# 4              86.0   168945.0
# 5-16          126.0   236523.0

# %%
# Create the figure and axes
fig, ax = plt.subplots(figsize=(10, 6)) 

# Extract data for plotting
x = minicubo_precio.loc['accommodates_disc'].index 
y1 = minicubo_precio.loc['accommodates_disc'].precio_total
y2 = minicubo_precio.loc['accommodates_disc'].price_buy

# Plot the first line (precio_total)
ax.plot(x, y1, label='Precio Total', color='blue', linewidth=2, marker='o', markersize=5) 

# Plot the second line (precio_compra) on the same axes
ax2 = ax.twinx()
ax2.plot(x, y2, label='price_buy', color='green', linewidth=2, marker='s', markersize=5)

# Set labels and title
ax.set_xlabel('Índice') 
ax.set_ylabel('Precio Total', color='blue')
ax2.set_ylabel('price_buy', color='green')
plt.title('Comparación de Precios por Categoría de Habitaciones')

# Customize gridlines
ax.grid(True, linestyle='--', alpha=0.5)
ax2.grid(True, linestyle='--', alpha=0.5)

# Add legends
lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax.legend(lines + lines2, labels + labels2, loc='upper left')

# Improve readability
plt.xticks(rotation=45) 

# Show the plot
plt.show()

# %% [markdown]
# **Insight 4: el número óptimo de huéspedes está en 3, ya el precio de los inmuebles para acomodar 3 es el mismo que para acomodar 1 o 2. A partir de 4 el piso necesita ser mayor y el precio de compra se incrementa bastante**

# %% [markdown]
# Por último vamos a analizar la variable que hemos construído de cercanía a un punto de interés para ver si tiene efecto sobre el precio de las habitaciones.
#
# En una situación real hubiéramos construído muchas de este tipo, y repetido el análisis con todas.
#
# En este caso como hemos construído la distancia a la Puerta del Sol vamos a evaluar solo los distritos para lo que esto puede ser relevante, es decir los más céntricos.
#
# Para ello primero vamos a calcular la distancia media por distrito y elegir un punto de corte.

# %%
df.groupby('distrito').pdi_sol.median().sort_values()
# Out:
# distrito
# Centro                    0.728581
# Arganzuela                1.817840
# Chamberí                  2.078790
# Moncloa - Aravaca         2.130135
# Retiro                    2.415432
# Salamanca                 2.705209
# Latina                    3.496952
# Carabanchel               3.647956
# Usera                     3.661376
# Chamartín                 4.233216
# Puente de Vallecas        4.233631
# Tetuán                    4.572866
# Ciudad Lineal             5.170226
# Moratalaz                 5.242395
# Villaverde                7.579665
# Fuencarral - El Pardo     7.738933
# San Blas - Canillejas     7.962141
# Hortaleza                 8.132864
# Vicálvaro                 8.396723
# Villa de Vallecas         8.822907
# Barajas                  11.593340
# Name: pdi_sol, dtype: float64

# %% [markdown]
# Vamos a cortar en Latina incluído.
#
# Y sobre esa selección vamos a visualizar con un scatter.

# %%
df.groupby('distrito').pdi_sol.median().sort_values()[0:7].index.to_list()
# Out:
# ['Centro',
#  'Arganzuela',
#  'Chamberí',
#  'Moncloa - Aravaca',
#  'Retiro',
#  'Salamanca',
#  'Latina']

# %%
seleccion = df.groupby('distrito').pdi_sol.median().sort_values()[0:7].index.to_list()

plt.figure(figsize = (16,12))
sns.scatterplot(data = df.loc[df.distrito.isin(seleccion)], x = 'pdi_sol', y = 'precio_total');

# %% [markdown]
# No parece haber una relación tan directa como sería esperable entre la distancia a la Puerta del Sol y el precio de alquiler.

# %% [markdown]
# **Insight 5: estando dentro del distrito parece que la cercanía a puntos de interés no tiene tanto impacto como sería esperable. Eso abre la puerta a buscar inmuebles que estando en un distrito céntrico no estén justo al lado del PdI y por tanto esperablmente tengan un precio de compra menor**

# %% [markdown]
# ### Analisis sobre la ocupación

# %% [markdown]
# Para este punto podríamos repetir exactamente los mismos análisis que con el precio pero cambiando la variable precio por la de ocupación que habíamos construido.
#
# Dado que sería igual no vamos a desarrollarlo y te lo dejo como tarea para que practiques e intentes obtener tus primeros insights.
#
# En su lugar prefiero el tiempo para enseñarte cómo podemos incluir análisis sobre un mapa, dado que en este caso sería algo muy relevante y es un tipo de análisis que siempre gusta mucho.

# %% [markdown]
# ### Analisis geográfico sobre un mapa

# %% [markdown]
# El análisis geográfico es una disciplina en si misma y de bastante complejidad.
#
# Pero afortunadamente hay una alternativa en Python que lo hace muy sencillo y cubre todo lo que necesitamos de forma práctica para nuestro fin.
#
# Es un paquete que se llama Folium y es una implementación de la tecnología Leaflet en Python.
#
# Lo único que necesitamos para usarlo es tener las coordenadas de latitud y longitud.

# %% [markdown]
# **Instalación:**
#
# conda install -c conda-forge folium
#
# **Importación:**
#
# import folium
#
# **Documentación:**
#
# https://python-visualization.github.io/folium/index.html

# %%
import folium

# %% [markdown]
# Con folium no es necesario instalar mapas, ya los trae por defecto, lo único que tenemos que hacer para inicializar un mapa es pasarle las coordenadas de inicio y opcionalmente un nivel de zoom.
#
# Vamos a usar las coordenadas de la Puerta del Sol que ya teníamos.

# %%
folium.Map(location=[40.4167278, -3.7033387],zoom_start=12)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_07d655c58591f8ed078c4e4fe26833f8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_07d655c58591f8ed078c4e4fe26833f8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_07d655c58591f8ed078c4e4fe26833f8 = L.map(
#                 &quot;map_07d655c58591f8ed078c4e4fe26833f8&quot;,
#                 {
#                     center: [40.4167278, -3.7033387],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2a1964853d79a31325102884375f4a6d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2a1964853d79a31325102884375f4a6d.addTo(map_07d655c58591f8ed078c4e4fe26833f8);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Por ejemplo vamos a analizar visualmente el insight sobre el distrito de San Blas.

# %%
datos = df[df.distrito == 'San Blas - Canillejas'].copy()

# %% [markdown]
# Para representar los marcadores de todos los pisos tenemos que crear un bucle para ir añadiéndolos al mapa.

# %%
mapa = folium.Map(location=[40.4167278, -3.7033387],zoom_start=12)

for piso in range(0,len(datos)):
   folium.Marker(
      location = [datos.iloc[piso]['latitude'], datos.iloc[piso]['longitude']],
      popup = datos.iloc[piso]['precio_total'],
   ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa073859cc709a26ef646a405ce89fb2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa073859cc709a26ef646a405ce89fb2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fa073859cc709a26ef646a405ce89fb2 = L.map(
#                 &quot;map_fa073859cc709a26ef646a405ce89fb2&quot;,
#                 {
#                     center: [40.4167278, -3.7033387],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e7f62a95ab0cc3f54316f8fc9d79fe3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1e7f62a95ab0cc3f54316f8fc9d79fe3.addTo(map_fa073859cc709a26ef646a405ce89fb2);
#
#
#             var marker_601edc45445031b3c2ae159f01875396 = L.marker(
#                 [40.43202, -3.60353],
#                 {}
#             ).addTo(map_fa073859cc709a26ef646a405ce89fb2);
#
#
#         var popup_8a3d2fca4fc8d189f2b6fcb302241d60 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c852fc3dedfe85848634d70316c98e86 = $(`&lt;div id=&quot;html_c852fc3dedfe85848634d70316c98e86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;36.0&lt;/div&gt;`)[0];
#                 popup_8a3d2fca4fc8d189f2b6fcb302241d60.setContent(html_c852fc3dedfe85848634d70316c98e86);
#
#
#
#         marker_601edc45445031b3c2ae159f01875396.bindPopup(popup_8a3d2fca4fc8d189f2b6fcb302241d60)
#         ;
#
#
#
#
#             var marker_c542bc4c2f3137f624fdef204d9ace40 = L.marker(
#                 [40.42756, -3.61577],
#                 {}
#             ).addTo(map_fa073859cc709a26ef646a405ce89fb2);
#
#
#         var popup_4df99a071b3f84473be40f19bd6ae915 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d809cb5c429cf92cdafa40b15be6f0c9 = $(`&lt;div id=&quot;html_d809cb5c429cf92cdafa40b15be6f0c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;29.4&lt;/div&gt;`)[0];
#                 popup_4df99a071b3f84473be40f19bd6ae915.setContent(html_d809cb5c429cf92cdafa40b15be6f0c9);
#
#
#
#         marker_c542bc4c2f3137f624fdef204d9ace40.bindPopup(popup_4df99a071b3f84473be40f19bd6ae915)
#         ;
#
#
#
#
#             var marker_1dd530973d86b19bcdea93539f174962 = L.marker(
#                 [40.42761, -3.6158],
#                 {}
#             ).addTo(map_fa073859cc709a26ef646a405ce89fb2);
#
#
#         var popup_78c023e98bc15ca857b4055ac6d9b6cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_14e2972754909cdcf8de815e2f120415 = $(`&lt;div id=&quot;html_14e2972754909cdcf8de815e2f120415&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;29.4&lt;/div&gt;`)[0];
#                 popup_78c023e98bc15ca857b4055ac6d9b6cb.setContent(html_14e2972754909cdcf8de815e2f120415);
#
#
#
#         marker_1dd530973d86b19bcdea93539f174962.bindPopup(popup_78c023e98bc15ca857b4055ac6d9b6cb)
#         ;
#
#
#
#
#             var marker_42369c299846f1b4379d99fe05701ab3 = L.marker(
#                 [40.4267, -3.61631],
#                 {}
#             ).addTo(map_fa073859cc709a26ef646a405ce89fb2);
#
#
#         var popup_1f988971d4689d628be0f7c87f3d77f6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_20559f8c83bac3d6d03d3d9d8cc112f5 = $(`&lt;div id=&quot;html_20559f8c83bac3d6d03d3d9d8cc112f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;21.0&lt;/div&gt;`)[0];
#                 popup_1f988971d4689d628be0f7c87f3d77f6.setContent(html_20559f8c83bac3d6d03d3d9d8cc112f5);
#
#
#
#         marker_42369c299846f1b4379d99fe05701ab3.bindPopup(popup_1f988971d4689d628be0f7c87f3d77f6)
#         ;
#
#
#
#
#             var marker_83509324eb40d597cd58d78e4b89a99c = L.marker(
#                 [40.44791, -3.57918],
#                 {}
#             ).addTo(map_fa073859cc709a26ef646a405ce89fb2);
#
#
#         var popup_d5055d071a02d545bd1b7f716a92c1f9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6b70e981d9676ebd9a7a41d0ba7e88a4 = $(`&lt;div id=&quot;html_6b70e981d9676ebd9a7a41d0ba7e88a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;85.0&lt;/div&gt;`)[0];
#                 popup_d5055d071a02d545bd1b7f716a92c1f9.setContent(html_6b70e981d9676ebd9a7a41d0ba7e88a4);
#
#
#
#         marker_83509324eb40d597cd58d78e4b89a99c.bindPopup(popup_d5055d071a02d545bd1b7f716a92c1f9)
#         ;
#
#
#
#
#             var marker_d85994157557b76722282bda80246bea = L.marker(
#                 [40.44655, -3.58128],
#                 {}
#             ).addTo(map_fa073859cc709a26ef646a405ce89fb2);
#
#
#         var popup_e4148c7cc39985ab6940c4efcd53158

# %% [markdown]
# Esta representación está bien, pero tenemos que ir haciendo click en cada uno para ver el precio.
#
# Sería más fácil si tuviéramos un código de colores que nos indicara visualmente el rango de precio.
#
# Para ello vamos a crear una nueva variable discretizada y cambiaremos el marcador a un círculo de colores.

# %%
datos['precio_total_disc'] = pd.qcut(datos['precio_total'], q = [0, .25, .5, .75, 1.], 
                              labels=['yellow', 'orange', 'blue', 'red'])

# %%
mapa = folium.Map(location=[40.4167278, -3.7033387],zoom_start=12)

for piso in range(0,len(datos)):
   folium.CircleMarker(
      location = [datos.iloc[piso]['latitude'], datos.iloc[piso]['longitude']],
      popup = datos.iloc[piso]['precio_total'],
      fill=True,
      color = datos.iloc[piso]['precio_total_disc'],
      fill_opacity=1,
      radius = 5
   ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ce3b4553bbf16be97fc02eae8b0f9eb2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ce3b4553bbf16be97fc02eae8b0f9eb2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ce3b4553bbf16be97fc02eae8b0f9eb2 = L.map(
#                 &quot;map_ce3b4553bbf16be97fc02eae8b0f9eb2&quot;,
#                 {
#                     center: [40.4167278, -3.7033387],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1b5ddaa35c6d2d3681ec35cd9b201b64 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1b5ddaa35c6d2d3681ec35cd9b201b64.addTo(map_ce3b4553bbf16be97fc02eae8b0f9eb2);
#
#
#             var circle_marker_c3da1080ed278bd091108c54572f8a9b = L.circleMarker(
#                 [40.43202, -3.60353],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ce3b4553bbf16be97fc02eae8b0f9eb2);
#
#
#         var popup_d0f6c6816ae8599927fc4c6ff60e267f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f206d63939beeee8ccf52bf99144f238 = $(`&lt;div id=&quot;html_f206d63939beeee8ccf52bf99144f238&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;36.0&lt;/div&gt;`)[0];
#                 popup_d0f6c6816ae8599927fc4c6ff60e267f.setContent(html_f206d63939beeee8ccf52bf99144f238);
#
#
#
#         circle_marker_c3da1080ed278bd091108c54572f8a9b.bindPopup(popup_d0f6c6816ae8599927fc4c6ff60e267f)
#         ;
#
#
#
#
#             var circle_marker_cad1d1e3665c77e447191eda9d3ebcb2 = L.circleMarker(
#                 [40.42756, -3.61577],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ce3b4553bbf16be97fc02eae8b0f9eb2);
#
#
#         var popup_88c23452c61d6b126f76200cda9a819c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7a83a692b625deb40d824a9ddd84b8d1 = $(`&lt;div id=&quot;html_7a83a692b625deb40d824a9ddd84b8d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;29.4&lt;/div&gt;`)[0];
#                 popup_88c23452c61d6b126f76200cda9a819c.setContent(html_7a83a692b625deb40d824a9ddd84b8d1);
#
#
#
#         circle_marker_cad1d1e3665c77e447191eda9d3ebcb2.bindPopup(popup_88c23452c61d6b126f76200cda9a819c)
#         ;
#
#
#
#
#             var circle_marker_1910deb61e56e1d7db445da3fa1fe097 = L.circleMarker(
#                 [40.42761, -3.6158],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ce3b4553bbf16be97fc02eae8b0f9eb2);
#
#
#         var popup_17d2076d00a4d036932fe09f932b01b8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_27fe827d9e93bd51cce722be16d4c375 = $(`&lt;div id=&quot;html_27fe827d9e93bd51cce722be16d4c375&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;29.4&lt;/div&gt;`)[0];
#                 popup_17d2076d00a4d036932fe09f932b01b8.setContent(html_27fe827d9e93bd51cce722be16d4c375);
#
#
#
#         circle_marker_1910deb61e56e1d7db445da3fa1fe097.bindPopup(popup_17d2076d00a4d036932fe09f932b01b8)
#         ;
#
#
#
#
#             var circle_marker_a2f8fdcda29f617645b5e45ff11a6a53 = L.circleMarker(
#                 [40.4267, -3.61631],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &qu

# %% [markdown]
# **Insight 6: Existen todavía muchos puntos amarillos y naranjas, lo cual puede indicar que todavía existe potencial para explotar más el factor de los eventos deportivos**
